# %% [markdown]
# # $Computer-Vision$

# %% [markdown]
# Computer vision is the ability of a computer to see --->
# - It is a filed of AI that helps computers/machines interpret and understanding visual information
#     - Images
#     - Videos
# - Applications
#     - medical imagining - tumor/cancer detection ---> using images of xray or MRI scans
#     - Self driving cars - lane detection, object detection
#     - Number plate detection - number plate detcted, recognized
#     - Image recognition - face ID, facial recognition, image detect ---> recognized, image classification
#     - Surveillance Systems - facial recognition
#     - Manufacturing lines - Robot arms, quality inspection,
#     -
#     - wherever you can use cameras
#
# - OPTIONAL --->
#     - Number Plate Detection project
#     - a system that detects whether an illegal car is parked in the parking
#     - set up a dictionary, database of allowed car number plates
#     - when a different number plate is parked in the parking for more than 5 minutes (or a day),
#         - flag the car, send a notification to a building administrator (telegram)

# %% [markdown]
# ### First step: an Image
# - What is an image?
#     - download an image into the work folder
